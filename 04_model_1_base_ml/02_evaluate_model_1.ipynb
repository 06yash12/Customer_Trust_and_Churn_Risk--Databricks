# %%
# Load Model-1 predictions
val_predictions = spark.table(
    "ai_trust_catalog.churn_trust.model_1_predictions"
)

display(val_predictions.select("label", "prediction", "probability"))

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# Evaluator for binary classification
evaluator = BinaryClassificationEvaluator(
    labelCol="label",
    rawPredictionCol="probability",
    metricName="areaUnderROC"
)

roc_auc = evaluator.evaluate(val_predictions)
print("Validation ROC-AUC:", roc_auc)

# %%
# Ensure evaluation succeeded
assert roc_auc is not None, "ROC-AUC is None. Evaluation failed."

# %%
# Count validation records
val_predictions.count()

# %%
# Inspect prediction outputs
val_predictions.select(
    "label",
    "prediction",
    "probability"
).show(5)

# %% [markdown]
# ## Summary
#
# - Evaluated Model-1 using ROC-AUC
# - Verified prediction outputs and probabilities
# - Confirmed validation dataset integrity
# - Established baseline performance for Trust Model comparison
